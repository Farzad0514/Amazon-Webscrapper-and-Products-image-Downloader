# %%
def getImages(url, fileName):
    import os
    import selenium 
    from selenium import webdriver
    
    driver = webdriver.Firefox(executable_path="C:/Users/Farzad/webDrivers/geckodriver.exe")
    
    import urllib.request
    import os
    
    
    #os.chdir(str(directory)+'/'+str(fileName))
    #retval = os.getcwd()
    #print(retval)
    #print()
    
    driver.get(url)
    
    #ivLargeImage
    get_images = driver.find_element_by_id('ivLargeImage')
    get_images = driver.find_element_by_id('altImages')
    images = get_images.find_elements_by_tag_name('img')
    
    image_list = []
    for each_image in images:
        image_list.append(each_image.get_attribute('src'))
    
    HQ_images= []
    for k in range (1, int(len(image_list))):
        HQ_images.append(image_list[k].replace("US40","SL1500"))
    
    for i in range (0, int(len(HQ_images))):

        titlePrefix= str(i+1)+str("_")
        try:
            print("Image number_" + str(i+1))
            print("Downloading starts...\n")
            urllib.request.urlretrieve(str(HQ_images[i]), str(titlePrefix) + str(fileName)+str('.jpg'))
            print(str((HQ_images[i])))
            print("Download completed..!!")
            print()
        except Exception as e:
            print(e)

    print("All files Downloaded")
    
    #driver.close()
    driver.quit()






# To download images in folders in a loop

def getImages_loop(csvfilePath, directory ):
    import pandas
    import time
    import os

    raw_dataUrl = pandas.read_csv(csvfilePath)
    dataUrl = raw_dataUrl['raw']
    os.chdir(directory)

    for i in range (0, int(len(dataUrl))):
    #for i in range (0, 1):

        fileName= 'prd_'+str(i+1)
        os.mkdir(fileName) # Make a folder
        os.chdir(fileName) #Change directory to new folder
        url = dataUrl[i]
        # download images
        try:
            getImages(url, fileName)
        except:
            print('getImages failed for: '+str(i))
            pass

        #parent = os.path.abspath('..')
        
        
        os.chdir(directory) # change directory to original path

        print('download completed for fileName: ' + str(fileName))
        
        time.sleep(10)

# %%
def getProductData(url):
    import os
    import selenium 
    from selenium import webdriver
    
    driver = webdriver.Firefox(executable_path="C:/Users/Farzad/webDrivers/geckodriver.exe")
    driver.get(url)
    
    singleProduct=[]
    
    try:
        get_title = driver.find_elements_by_class_name("product-title-word-break")
        title = get_title[0].text
    except: pass
        
    try: 
    #feature-bullets
        get_des = driver.find_elements_by_id("feature-bullets")
        strDes = str(get_des[0].text.split('\n'))
        des= strDes.replace("]", "").replace("[", "")
    except: pass

    try:
        #a-keyvalue prodDetTable
        get_details = driver.find_elements_by_class_name("prodDetTable")
        strDetails = str(get_details[0].text.split('\n'))
        details= strDetails.replace("]", "").replace("[", "")
    except: pass
    
    try:
    #productDescription
        get_long_des = driver.find_element_by_id('productDescription')
        strLong_des = str(get_long_des.text.split('\n'))
        long_des= strLong_des.replace("]", "").replace("[", "")
        
    except: pass
    try: 
        get_availability = driver.find_element_by_id('availability')
        availability = get_availability.text.split('\n')
        
    except: pass
        
    try:
        get_brand = driver.find_element_by_id('bylineInfo')
        strBrand= str(get_brand.text.split('\n'))
        brand= strBrand[9:].replace("]", "").replace("'", "")
    except: pass

    try:
    #buybox-tabular-content
        get_sellerDetails = driver.find_elements_by_class_name("buybox-tabular-content")
    except: pass
    
    try:
        shipsFrom= get_sellerDetails[0].text
    except: pass
        
    try:
        soldBy= get_sellerDetails[1].text
    except: pass
    #priceblock_ourprice
    try:
        get_price = driver.find_element_by_id('priceblock_ourprice')
        price = get_price.text
    except: pass
    #return title, brand, des, details, long_des, availability, shipsFrom, soldBy, price, url

    d={}

    
    try: d['title']=title
    except:d['title']=None
    try: d['brand']= brand
    except:d['brand']=None
    try: d['description']= des
    except:d['description']=None
    try: d['details']= details
    except:d['details']=None
    try: d['long description']=long_des
    except:d['long description']=None
    try: d['availability']= availability
    except:d['availability']=None
    try: d['ships from']= shipsFrom
    except:d['ships from']=None
    try: d['sold by']=soldBy
    except:d['sold by']=None
    try: d['price']= price
    except:d['price']=None
    try: d['product url']= url
    except:d['product url']=None

    singleProduct.append(d)

    import pandas
    
    df_mini = pandas.DataFrame(singleProduct)
    
    driver.close()
    driver.quit()
    
    return df_mini







def getProductData_Loop(directory, csvfilePath, fileName):
    
    import pandas
    import time
    import os

    #raw_dataUrl = pandas.read_csv("D:/Ebay/aus/oct/productsUrl.csv")
    raw_dataUrl = pandas.read_csv(csvfilePath)
    dataUrl = raw_dataUrl['raw']
    #directory= 'D:/Ebay/aus/oct/'
    os.chdir(directory)

    l=getProductData(dataUrl[0])
    
    
    for i in range(1, len(dataUrl)):
    #for i in range(1, 3):

        try: 
            url = dataUrl[i]

            l= l.append(getProductData(dataUrl[i]))
    
            
        except:
            print('Failed getProductData_Loop for: ' +(str(i)))
            pass

        time.sleep(10)
        
    df= l.to_csv(fileName + str('.csv'))
        
    location= os.getcwd()
        
    return l.shape, print('csv File is saved at:' + str(location))

# %%
directory= input('directory :')
csvfilePath= input('csvfilePath :')
fileName = input('fileName: ')

getProductData_Loop(directory, csvfilePath, fileName)
# Out:
# directory :D:/Ebay/aus/oct/
# csvfilePath :D:/Ebay/aus/oct/productsUrl.csv
# fileName: data_v2
# csv File is saved at:D:\Ebay\aus\oct
# ((30, 10), None)

# %%
directory= input('directory :')
csvfilePath= input('csvfilePath :')


getImages_loop(csvfilePath, directory )
# Out:
# directory :D:/Ebay/aus/oct/
# csvfilePath :D:/Ebay/aus/oct/productsUrl.csv
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41WkEvFI%2B9L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/411ovVNBqdL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41dSp790baL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51Tv840324L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41saYAQRDyL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41vPWvDx%2BfL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41a2achseeL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_1
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41EHEfdpytL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41MnUdnPHmL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51AeTHpB2SL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41qUbTCEazL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41%2B1taSe6BL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51DvtBuED%2BL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41QFCBy-TLL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_2
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41PR52HL2OL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41U27RzDkJL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51s3ssRZL3L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51dPKYA9OdL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41wpL53p-FL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31K3J7wpHbL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41O7gxaiZtL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_3
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31j5gAs%2BGDL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31RQx1Sht8L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/313W7H6eMZL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/2136g1vUbFL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_4
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31fUjpFhPzL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41tQNk%2BuLfL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51hY0LxcU6L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51ix6eEuNcL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51NqvuutyPL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/519feVmb7SL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_5
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41wof2kJvkL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41wof2kJvkL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41d1XpaclNL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31cK%2Bpd3JnL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41wUxuv5jSL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31ucxmZASSL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41bBbmXxdCL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_6
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/21E%2BeIiTO8L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/315Uxk0rmhL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/215m5RnVPrL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/218mqkQbTBL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31wx9LFjZxL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/219kzvd2sWL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51vEOSG3a%2BL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_7
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31uyySwhzZL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31Mepyl1MyL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31M8WE6LEBL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41Z6%2BTV%2BSvL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/315iTSXUgRL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/416EeXYU7tL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_8
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31QiBxMPIZL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_9
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/21UkyptwUYL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41GKvZp%2ByQL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51TeWjwYfxL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
# https://images-na.ssl-images-amazon.com/images/I/41H2Y2SFVwL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41q%2BVMFGWXL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41myiM5rIlL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41MEUM92UgL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_10
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31W2gP1HJ3L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51F8888kEKL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_11
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31vatA%2B3%2BFL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41Uh-k3HWkL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41jJEOXdo-L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41982H8bHlL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41yGMx4zBDL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_12
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41w56W4p3BL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41MLuVTXrnL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/412xz2tmV7L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41y9-B4jzJL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41k58sy-P6L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/310TLQGv28L._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_13
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51EzYUdNX5L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51DACzkqYgL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51UAP2BokOL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51glx0Vb71L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51vlJ7LSj3L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51EbUfA-dcL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51yvX9doXDL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_14
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41bFIspBnoL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_15
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41UYqcxIYJL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41wN0EWJyzL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_16
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31xoXcZIOUL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31DKsIN4UcL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31M04gR%2BfhL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_17
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51vol50M96L._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_18
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31TYeUxcflL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31iuN9FQN9L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41BYT4PSYEL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/415cpwuzntL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41l1CYkGUlL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_19
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31FjsuTDMpL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51UiT3IoM-L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/513-Q4EsXYL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41oMHv7gZQL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41--ZdeAC9L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51IUdE6NM0L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/61IiyZhT-GL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_20
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31bsix-WjML._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31aY4PfP%2BxL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31zxfTS00qL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_21
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41ThjS6fi6L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41oibYa2dYL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51qlxggxKyL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41t7BnUHWdL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41imHxutH4L._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_22
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31%2BOwkQCZrL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41ENE7kkjWL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/314Akjz-74L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
# https://images-na.ssl-images-amazon.com/images/I/41rcjmGQHXL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51bnvEZslVL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/5167-9dYlXL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_23
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31aBjMvDLhL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51rmQqmQztL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41o84pzhRSL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51LY25HjhiL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31eWJFhHolL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41V49Cvep0L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41xbEJl6VoL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_24
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/417Fl53eS-L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41vvZKh8e3L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51Y4BZNWaUL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41Wh%2BzmgTsL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/416ltcPvQmL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41OqMVJ71nL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41Ig04s1agL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_25
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41JT8GFU6TL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/313jLFC7u9L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41dYaE%2BeG6L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41ti%2Bl5lW9L._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_26
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41YLc4cF2bL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/412FF0CLiiL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/412FF0CLiiL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41RN9x7sCFL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_27
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31HnMq%2Bhv-L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/4102lzg7CJL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41-Il-T1pFL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31z03pJO6eL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41wRY4Q4KnL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_28
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/31wUSHi3YTL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41sUpSLuoZL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/417O-Qnd2lL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/61kB5sNEHmL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_29
# Image number_1
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41rtlVJ5y1L._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_2
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41f6vygUetL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_3
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41f-SSVb4ZL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_4
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41uhGQQkREL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_5
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41NLblNq6WL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_6
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/51HRxIFXJCL._AC_SL1500_.jpg
# Download completed..!!
#
# Image number_7
# Downloading starts...
#
# https://images-na.ssl-images-amazon.com/images/I/41pHrB0-ImL._AC_SL1500_.jpg
# Download completed..!!
#
# All files Downloaded
# download completed for fileName: prd_30

# %%
D:/Ebay/aus/oct/
D:/Ebay/aus/oct/productsUrl.csv
test
